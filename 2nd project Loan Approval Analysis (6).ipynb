# %% [markdown]
# # The objective of this project is to analyze loan applications and identify the factors affecting loan approval and rejection.

# %% [markdown]
# **importing  pandas libary for uses of pandas function**
# **importing numpy libary for uses of numpy function**

# %%
import pandas as pd
import numpy as np

# %%
loan=pd.read_csv("Loan_Approval_Analysis_Dataset.csv")

# %% [markdown]
# **The loan dataset is loaded into a Pandas DataFrame using read_csv().**

# %%
loan
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 0                  1      NaN         Single          0  Not Graduate
# 1                  2  Female         Married         3+      Graduate
# 2                  3     male         Single         3+      Graduate
# 3                  4     male        Widowed          2      Graduate
# 4                  5      NaN            NaN          1  Not Graduate
# ...              ...      ...            ...        ...           ...
# 3515            2334   Female        Widowed          0  Not Graduate
# 3516            1743      NaN        Widowed         3+      Graduate
# 3517             614        M            NaN          1      Graduate
# 3518             137      NaN         Single          0      Graduate
# 3519             350     Male            NaN          1      Graduate
#
#      Self_Employed Employment_Type  Annual_Income  Coapplicant_Income  \
# ...

# %% [markdown]
# ### Display dataset

# %% [markdown]
# ## The dataset is checked for missing values, duplicate records, incorrect data types, and unnecessary data before analysis.
#  ✅ Data Cleaning
#  ✅ Missing Value Handling
#  ✅ Duplicate Removal

# %%
loan
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 0                  1      NaN         Single          0  Not Graduate
# 1                  2  Female         Married         3+      Graduate
# 2                  3     male         Single         3+      Graduate
# 3                  4     male        Widowed          2      Graduate
# 4                  5      NaN            NaN          1  Not Graduate
# ...              ...      ...            ...        ...           ...
# 3515            2334   Female        Widowed          0  Not Graduate
# 3516            1743      NaN        Widowed         3+      Graduate
# 3517             614        M            NaN          1      Graduate
# 3518             137      NaN         Single          0      Graduate
# 3519             350     Male            NaN          1      Graduate
#
#      Self_Employed Employment_Type  Annual_Income  Coapplicant_Income  \
# ...

# %% [markdown]
# **using insert function for inserting new column and their data on 3rd position**

# %%
loan.insert(5,"Country","INDIA")

# %% [markdown]
# **using insert function for inserting new column and their data on 5th position**

# %%
city=["Mumbai", "Pune", "Delhi", "Bengaluru", "Hyderabad",
    "Chennai", "Kolkata", "Ahmedabad", "Jaipur", "Lucknow",
    "Nagpur", "Nashik", "Surat", "Indore", "Bhopal",
    "Patna", "Kanpur", "Visakhapatnam", "Chandigarh", "Kochi"
]

loan.insert(5, "City", np.random.choice(city, len(loan)))

# %% [markdown]
# **creted list for storing cities values then using insert function for adding new  city colunm and their data on 5th positon**

# %%
loan.isnull().sum()
# Out:
# Application_ID             0
# Gender                   763
# Marital_Status           699
# Dependents                 0
# Education                  0
# City                       0
# Country                    0
# Self_Employed              0
# Employment_Type            0
# Annual_Income            176
# Coapplicant_Income         0
# Loan_Amount              176
# Loan_Term_Months           0
# Credit_History           874
# Credit_Score             336
# Existing_Loans             0
# Debt_To_Income_Ratio       0
# Property_Area              0
# Residence_Type             0
# Age                        0
# Work_Experience_Years      0
# Monthly_Expenses           0
# Savings_Balance          176
# Bank_Balance               0
# Employment_Stability       0
# Collateral_Value           0
# Previous_Default           0
# Loan_Purpose               0
# Application_Channel        0
# Risk_Level                 0
# Loan_Status                0
# Approval_Reason          597
# ...

# %% [markdown]
# **used isna() and sum() for displaying which total number of NaN value in dataset**

# %%
loan.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **used duplicated() is check duplicate value is persent or not in dataset sum() function for displaying which total number of duplicated values in dataset**

# %%
loan.drop_duplicates(inplace=True)

# %% [markdown]
# **drop_duplicates() is use for deleting duplicates value about the dataset and used between the function inplace = True it is use for perform the operation on original dataset and commit this change**

# %%
loan
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 0                  1      NaN         Single          0  Not Graduate
# 1                  2  Female         Married         3+      Graduate
# 2                  3     male         Single         3+      Graduate
# 3                  4     male        Widowed          2      Graduate
# 4                  5      NaN            NaN          1  Not Graduate
# ...              ...      ...            ...        ...           ...
# 3515            2334   Female        Widowed          0  Not Graduate
# 3516            1743      NaN        Widowed         3+      Graduate
# 3517             614        M            NaN          1      Graduate
# 3518             137      NaN         Single          0      Graduate
# 3519             350     Male            NaN          1      Graduate
#
#             City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# # ✅ Missing Values handling  NaN values
#
# #Fill categorical columns

# %%
loan["Marital_Status"]=loan["Marital_Status"].fillna("Single")

# %% [markdown]
# **access The Marital_Status column for fillign their NaN values then filled their values using fillna() function and fill Single where NaN persent and loaded into the original dataset**

# %%
loan["Gender"]=loan["Gender"].replace(to_replace=np.nan,value="Male")

# %% [markdown]
# **access the Gender column for filling their NaN values then filled their values using replace() function between the replace function used to_replace menthod is assign equal to np.Nan and replacing equal to value " Male" string and loaded into the original dataset**

# %%
loan["Credit_History"]=loan["Credit_History"].fillna("Good")

# %% [markdown]
# **Accessed the Credit_History column and replaced all missing (NaN) values with "Good" using the fillna() function. The updated values were then saved back into the original dataset.**

# %%
loan["Approval_Reason"]=loan["Approval_Reason"].fillna("Pending")

# %% [markdown]
# **Accessed the Approval_Reason column and replaced all missing (NaN) values with "Pending" using the fillna() function. The updated values were then saved back into the original dataset.**

# %%
#fill numerical columns

# %%
loan["Annual_Income"]=loan["Annual_Income"].fillna(loan["Annual_Income"].median())

# %% [markdown]
# **Accessed the Annual_Income column and calculated its median value. Then, using the fillna() function, replaced all missing (NaN) values with the median and saved the updated values back into the original dataset.**

# %%
loan["Loan_Amount"]=loan["Loan_Amount"].fillna(loan["Loan_Amount"].median())

# %% [markdown]
# **Accessed the Loan_Amount column and calculate its median value .Then ,using the fillna function ,replaced all missing (NaN) values with the median and saved the update value back into the original dataset**

# %%
loan["Credit_Score"]=loan["Credit_Score"].fillna(loan["Credit_Score"].median())

# %% [markdown]
# **Accessed the Credit_Score column and calculate its median value .Then ,using the fillna function ,replaced all missing (NaN) values with the median and saved the update value back into the original dataset**

# %%
loan["Savings_Balance"]=loan["Savings_Balance"].fillna(loan["Savings_Balance"].median())

# %% [markdown]
# **Accessed the Savings_Balance column and calculate its median value .Then ,using the fillna function ,replaced all missing (NaN) values with the median and saved the update value back into the original dataset**

# %% [markdown]
# **Displaying without any missing value and clean data**

# %%
loan
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 0                  1     Male         Single          0  Not Graduate
# 1                  2  Female         Married         3+      Graduate
# 2                  3     male         Single         3+      Graduate
# 3                  4     male        Widowed          2      Graduate
# 4                  5     Male         Single          1  Not Graduate
# ...              ...      ...            ...        ...           ...
# 3515            2334   Female        Widowed          0  Not Graduate
# 3516            1743     Male        Widowed         3+      Graduate
# 3517             614        M         Single          1      Graduate
# 3518             137     Male         Single          0      Graduate
# 3519             350     Male         Single          1      Graduate
#
#             City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# # Then now no any missing(NaN)values in dataset

# %%
loan.isna().sum()
# Out:
# Application_ID           0
# Gender                   0
# Marital_Status           0
# Dependents               0
# Education                0
# City                     0
# Country                  0
# Self_Employed            0
# Employment_Type          0
# Annual_Income            0
# Coapplicant_Income       0
# Loan_Amount              0
# Loan_Term_Months         0
# Credit_History           0
# Credit_Score             0
# Existing_Loans           0
# Debt_To_Income_Ratio     0
# Property_Area            0
# Residence_Type           0
# Age                      0
# Work_Experience_Years    0
# Monthly_Expenses         0
# Savings_Balance          0
# Bank_Balance             0
# Employment_Stability     0
# Collateral_Value         0
# Previous_Default         0
# Loan_Purpose             0
# Application_Channel      0
# Risk_Level               0
# Loan_Status              0
# Approval_Reason          0
# dtype: int64

# %% [markdown]
# # Data Formating

# %%
loan.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3520 entries, 0 to 3519
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Application_ID         3520 non-null   int64
#  1   Gender                 3520 non-null   str
#  2   Marital_Status         3520 non-null   str
#  3   Dependents             3520 non-null   str
#  4   Education              3520 non-null   str
#  5   City                   3520 non-null   str
#  6   Country                3520 non-null   str
#  7   Self_Employed          3520 non-null   str
#  8   Employment_Type        3520 non-null   str
#  9   Annual_Income          3520 non-null   float64
#  10  Coapplicant_Income     3520 non-null   int64
#  11  Loan_Amount            3520 non-null   float64
#  12  Loan_Term_Months       3520 non-null   int64
#  13  Credit_History         3520 non-null   str
#  14  Credit_Score           3520 non-null   float64
# ...

# %%
loan.shape
# Out:
# (3520, 32)

# %%
loan.dtypes
# Out:
# Application_ID             int64
# Gender                       str
# Marital_Status               str
# Dependents                   str
# Education                    str
# City                         str
# Country                      str
# Self_Employed                str
# Employment_Type              str
# Annual_Income            float64
# Coapplicant_Income         int64
# Loan_Amount              float64
# Loan_Term_Months           int64
# Credit_History               str
# Credit_Score             float64
# Existing_Loans             int64
# Debt_To_Income_Ratio     float64
# Property_Area                str
# Residence_Type               str
# Age                        int64
# Work_Experience_Years      int64
# Monthly_Expenses           int64
# Savings_Balance          float64
# Bank_Balance               int64
# Employment_Stability         str
# Collateral_Value           int64
# Previous_Default             str
# Loan_Purpose                 str
# ...

# %%
loan.columns
# Out:
# Index(['Application_ID', 'Gender', 'Marital_Status', 'Dependents', 'Education',
#        'City', 'Country', 'Self_Employed', 'Employment_Type', 'Annual_Income',
#        'Coapplicant_Income', 'Loan_Amount', 'Loan_Term_Months',
#        'Credit_History', 'Credit_Score', 'Existing_Loans',
#        'Debt_To_Income_Ratio', 'Property_Area', 'Residence_Type', 'Age',
#        'Work_Experience_Years', 'Monthly_Expenses', 'Savings_Balance',
#        'Bank_Balance', 'Employment_Stability', 'Collateral_Value',
#        'Previous_Default', 'Loan_Purpose', 'Application_Channel', 'Risk_Level',
#        'Loan_Status', 'Approval_Reason'],
#       dtype='str')

# %%
loan.describe()
# Out:
#        Application_ID  Annual_Income  Coapplicant_Income    Loan_Amount  \
# count     3520.000000    3520.000000         3520.000000    3520.000000
# mean      1750.739773   60296.138920        20386.856818  252940.233807
# std       1010.875620   24168.261792        13893.829406   95721.100731
# min          1.000000   10000.000000            0.000000    5000.000000
# 25%        875.750000   43433.750000         9259.500000  190910.250000
# 50%       1750.500000   60411.500000        19677.000000  250461.000000
# 75%       2625.250000   76538.250000        29821.750000  314115.500000
# max       3500.000000  154437.000000        72344.000000  644233.000000
#
#        Loan_Term_Months  Credit_Score  Existing_Loans  Debt_To_Income_Ratio  \
# count       3520.000000   3520.000000     3520.000000           3520.000000
# mean         190.653409    651.050568        2.523295             34.912631
# std          102.500836    110.124088        1.709350             17.370631
# ...

# %%
loan.sample(2)
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 561              562  Female         Widowed          2      Graduate
# 1443            1444     male        Married          2  Not Graduate
#
#                City Country Self_Employed Employment_Type  Annual_Income  ...  \
# 561           Delhi   INDIA           Yes         Private        56264.0  ...
# 1443  Visakhapatnam   INDIA            No        Business        50980.0  ...
#
#       Savings_Balance  Bank_Balance  Employment_Stability Collateral_Value  \
# 561           57381.0        250759                Medium            28496
# 1443          36201.0        195662                   Low           438140
#
#       Previous_Default  Loan_Purpose  Application_Channel Risk_Level  \
# 561                 No          Home               Branch       High
# 1443               Yes      Personal                Agent        Low
#
#      Loan_Status  Approval_Reason
# 561     Approved         Eligible
# ...

# %%
loan.index
# Out:
# RangeIndex(start=0, stop=3520, step=1)

# %% [markdown]
# # Cheking columns data

# %%
loan["City"].unique()
# Out:
# <ArrowStringArray>
# [   'Chandigarh',        'Nashik',         'Kochi',         'Patna',
#          'Surat',       'Lucknow',          'Pune',        'Bhopal',
#         'Kanpur',       'Chennai',        'Jaipur', 'Visakhapatnam',
#         'Nagpur',        'Indore',     'Bengaluru',     'Ahmedabad',
#         'Mumbai',         'Delhi',     'Hyderabad',       'Kolkata']
# Length: 20, dtype: str

# %%
loan["Education"].unique()
# Out:
# <ArrowStringArray>
# ['Not Graduate', 'Graduate']
# Length: 2, dtype: str

# %%
loan["Employment_Type"].unique()
# Out:
# <ArrowStringArray>
# ['Government', 'Business', 'Private', 'Self-Employed']
# Length: 4, dtype: str

# %%
loan["Property_Area"].unique()
# Out:
# <ArrowStringArray>
# ['Rural', 'Semiurban', 'Urban']
# Length: 3, dtype: str

# %%
loan["Work_Experience_Years"].unique()
# Out:
# array([27, 21,  4, 10, 13, 32,  5,  7,  3,  9, 25, 20, 33, 16, 35, 11, 12,
#        19, 15, 34, 14,  1,  0, 17, 23,  2, 30, 22, 28, 29, 31, 26, 24,  8,
#        18,  6])

# %% [markdown]
# # Using NUMPY ARITHMETICAL OPERATION on dataset

# %%
import numpy as np

# %%
loan["Loan_Purpose"].mode()
# Out:
# 0    Home
# Name: Loan_Purpose, dtype: str

# %%
loan[loan["Loan_Purpose"]=="Home"].value_counts().sum()
# Out:
# np.int64(735)

# %%
loan["Loan_Amount"].sum()
# Out:
# np.float64(890349623.0)

# %%
loan["Collateral_Value"].median()
# Out:
# np.float64(298194.0)

# %%
loan["Debt_To_Income_Ratio"].min()
# Out:
# np.float64(5.03)

# %%
loan["Debt_To_Income_Ratio"].max()
# Out:
# np.float64(64.97)

# %%
loan["Monthly_Expenses"].quantile(0.25)
# Out:
# np.float64(18147.0)

# %%
loan["Monthly_Expenses"].quantile(0.75)
# Out:
# np.float64(31768.5)

# %%
loan["Monthly_Expenses"].quantile(0.100)
# Out:
# np.float64(12225.9)

# %%
loan["Credit_Score"].sort_values(ascending=False).head()
# Out:
# 2403    850.0
# 2579    850.0
# 1503    850.0
# 2621    850.0
# 1175    850.0
# Name: Credit_Score, dtype: float64

# %%
np.std(loan["Annual_Income"])
# Out:
# np.float64(24164.828556818215)

# %%
loan["Savings_Balance"].mean()
# Out:
# np.float64(104375.83607954545)

# %% [markdown]
# # Condition Questoin

# %%
numeric_cols = loan.select_dtypes(include="number")

corr = numeric_cols.corr()

# %%
numeric_cols
# Out:
#       Application_ID  Annual_Income  Coapplicant_Income  Loan_Amount  \
# 0                  1        72417.0               29715     236173.0
# 1                  2        46870.0                6138     250461.0
# 2                  3        37299.0               41984     108769.0
# 3                  4        47114.0               34211     189974.0
# 4                  5        80563.0               23132     127915.0
# ...              ...            ...                 ...          ...
# 3515            2334        38020.0                6672     484064.0
# 3516            1743        10000.0               11942     287574.0
# 3517             614        50357.0               17955     250461.0
# 3518             137        51959.0               25729     457674.0
# 3519             350        72494.0               65929     151973.0
#
#       Loan_Term_Months  Credit_Score  Existing_Loans  Debt_To_Income_Ratio  \
# ...

# %%
loan[(loan["Employment_Type"]=="Government")&(loan["Annual_Income"]>=80000)]
# Out:
#       Application_ID  Gender Marital_Status Dependents     Education  \
# 4                  5    Male         Single          1  Not Graduate
# 13                14    Male       Divorced          0      Graduate
# 19                20  Female         Single         3+      Graduate
# 26                27    male         Single          0      Graduate
# 44                45    Male        Widowed          0      Graduate
# ...              ...     ...            ...        ...           ...
# 3394            3395  Female        Married         3+  Not Graduate
# 3420            3421  Female        Widowed          1  Not Graduate
# 3441            3442    male         Single          2  Not Graduate
# 3457            3458    Male         Single          1      Graduate
# 3501             976    male         Single         3+      Graduate
#
#             City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# ### conclusion : 184 Borrower are government empolyees and there Annual Income is greater than 80000

# %%
loan[(loan["Gender"]=="male")|(loan["Gender"]=="Male")]
# Out:
#       Application_ID Gender Marital_Status Dependents     Education  \
# 0                  1   Male         Single          0  Not Graduate
# 2                  3   male         Single         3+      Graduate
# 3                  4   male        Widowed          2      Graduate
# 4                  5   Male         Single          1  Not Graduate
# 7                  8   male        Married          0  Not Graduate
# ...              ...    ...            ...        ...           ...
# 3511             298   Male        Widowed          0  Not Graduate
# 3513            3252   Male        Married          2  Not Graduate
# 3516            1743   Male        Widowed         3+      Graduate
# 3518             137   Male         Single          0      Graduate
# 3519             350   Male         Single          1      Graduate
#
#             City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# ### conclusion :1858 Borrower are Male

# %%
loan[(loan["Gender"]=="Female")&(loan["Self_Employed"]=="No")]
# Out:
#       Application_ID  Gender Marital_Status Dependents     Education  \
# 5                  6  Female         Single          2  Not Graduate
# 11                12  Female        Widowed          1  Not Graduate
# 19                20  Female         Single         3+      Graduate
# 22                23  Female        Widowed         3+      Graduate
# 54                55  Female       Divorced         3+  Not Graduate
# ...              ...     ...            ...        ...           ...
# 3480            3481  Female        Married          0  Not Graduate
# 3484            3485  Female         Single         3+  Not Graduate
# 3486            3487  Female         Single          2      Graduate
# 3488            3489  Female       Divorced         3+      Graduate
# 3515            2334  Female        Widowed          0  Not Graduate
#
#             City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# ### conclsion : 267 Female Borrower are No self employed

# %%
loan[loan["City"]=="Mumbai"]
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education    City  \
# 50                51     Male       Divorced         3+      Graduate  Mumbai
# 64                65  Female          Single          1      Graduate  Mumbai
# 156              157     male         Single          2      Graduate  Mumbai
# 179              180     Male       Divorced          2  Not Graduate  Mumbai
# 181              182     Male        Married          2  Not Graduate  Mumbai
# ...              ...      ...            ...        ...           ...     ...
# 3403            3404  Female         Married         3+      Graduate  Mumbai
# 3412            3413   Female        Widowed          1  Not Graduate  Mumbai
# 3425            3426  Female          Single          0  Not Graduate  Mumbai
# 3459            3460     male       Divorced          2  Not Graduate  Mumbai
# 3510            2360        M         Single          0  Not Graduate  Mumbai
#
# ...

# %% [markdown]
# ### conclusion :180 Borrower they live in mumbai

# %%
loan[(loan["Loan_Purpose"]=="Education")&(loan["Loan_Status"]=="Rejected")]
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 2                  3     male         Single         3+      Graduate
# 35                36        M       Divorced          2  Not Graduate
# 42                43     Male       Divorced          0      Graduate
# 46                47     Male       Divorced         3+  Not Graduate
# 57                58        M       Divorced          0  Not Graduate
# ...              ...      ...            ...        ...           ...
# 3467            3468  Female          Single          1  Not Graduate
# 3474            3475     Male        Widowed         3+      Graduate
# 3486            3487   Female         Single          2      Graduate
# 3488            3489   Female       Divorced         3+      Graduate
# 3510            2360        M         Single          0  Not Graduate
#
#          City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# ### conclusion : 204 Borrower are approved loan for education and there loan are rejected

# %%
loan[(loan["Employment_Type"]=="Business")&(loan["Existing_Loans"]>=5)]
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 1                  2  Female         Married         3+      Graduate
# 3                  4     male        Widowed          2      Graduate
# 114              115     male        Married          1  Not Graduate
# 167              168     Male         Single          1      Graduate
# 230              231        M        Married          2  Not Graduate
# ...              ...      ...            ...        ...           ...
# 3442            3443     male         Single          2  Not Graduate
# 3448            3449        M         Single          2  Not Graduate
# 3459            3460     male       Divorced          2  Not Graduate
# 3473            3474     Male         Single          1  Not Graduate
# 3483            3484     Male         Single          1  Not Graduate
#
#          City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# ### conclusion : 140 The person doing business has had an existing loan for more than 5 years.

# %%
loan[((loan["Dependents"]=="3+")&(loan["Application_ID"]))&((loan["Bank_Balance"]<=50000)&(loan["Loan_Purpose"]=="Education"))]
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 118              119        M         Single         3+  Not Graduate
# 268              269     male         Single         3+      Graduate
# 298              299  Female         Widowed         3+  Not Graduate
# 428              429   Female        Married         3+  Not Graduate
# 690              691  Female          Single         3+  Not Graduate
# 742              743     Male       Divorced         3+  Not Graduate
# 840              841     Male        Married         3+      Graduate
# 1058            1059     Male         Single         3+  Not Graduate
# 1230            1231  Female          Single         3+  Not Graduate
# 1304            1305   Female        Widowed         3+  Not Graduate
# 1476            1477     male        Widowed         3+  Not Graduate
# 1566            1567     male         Single         3+  Not Graduate
# ...

# %% [markdown]
# ### conclusion :20 borrower who has 3+ dependents, a bank balance of less than 50,000, and whose loan purpose is education.

# %%
loan[(loan["Application_Channel"]=="Agent")&(loan["Loan_Status"]=="Rejected")]
# Out:
#       Application_ID   Gender Marital_Status Dependents     Education  \
# 14                15     Male         Single          2  Not Graduate
# 18                19     male        Married          1      Graduate
# 24                25        M        Married          1      Graduate
# 35                36        M       Divorced          2  Not Graduate
# 38                39  Female        Divorced          0      Graduate
# ...              ...      ...            ...        ...           ...
# 3495            3496   Female        Widowed          1      Graduate
# 3499            3500     male         Single          1  Not Graduate
# 3503            1264        M         Single          1      Graduate
# 3509             331        M       Divorced          1      Graduate
# 3515            2334   Female        Widowed          0  Not Graduate
#
#                City Country Self_Employed Employment_Type  Annual_Income  ...  \
# ...

# %% [markdown]
# ### conclusion : 366 Borrower got the loan approved through the agent, and it got rejected.

# %% [markdown]
# # Using Pandas with plot

# %%
loan["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
loan.groupby("Loan_Purpose")["Application_ID"].mean().plot(kind="pie",title="The Loan Purpose")
# Out:
# <Axes: title={'center': 'The Loan Purpose'}>

# %% [markdown]
# # **Now we are going to solve the problem using the Matplotlib library**
# ### Applicants are grouped based on factors such as employment, income, credit score, risk level, and loan purpose to identify different applicant segments.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
em=loan.groupby("Employment_Type")["Annual_Income"].mean()

# %%
x=em.index

# %%
y=em.values

# %%
plt.figure(figsize=(8,5),facecolor="#FEF2A0",edgecolor="#133458")
plt.pie(y,labels=x,autopct="%1.1f%%",shadow=0.9)
plt.legend()
plt.show()

# %% [markdown]
# ### conclusion :25.2%  of employees who take loans are from the private sector

# %%
graph=loan.groupby("Marital_Status")["Work_Experience_Years"].mean()

# %%
o=graph.index

# %%
t=graph.values

# %%
plt.figure(figsize=(6,7),facecolor="#FDF0D5")
plt.title("Loan Member Merital Status",color="#224248",size="large",weight="bold")
plt.grid()
plt.xlabel("Marital Status")
plt.ylabel("Work Experience")
plt.plot(o,t,marker="H",mfc="#5D3140",mec="#E9C46A",ms=9)
plt.show()

# %% [markdown]
# ### conclusion :18.0 Widowed  have more work experience

# %%
status=loan.groupby("Loan_Status")["Application_ID"].median()

# %%
n=status.index

# %%
v=status.values

# %%
plt.figure(figsize=(6,8),facecolor="#FFE2E2")
plt.title("Loan Status Analysis",color="#BA5A5A",size="large",weight="bold")
plt.pie(v,labels=n,autopct="%1.1f%%")
plt.legend()
plt.show()

# %% [markdown]
# ### conclusion :49.1% of loans are approved and 50.9% of loans are rejected

# %%
collateral=loan.groupby("Employment_Type")["Collateral_Value"].sum().sort_values()

# %%
co=collateral.index

# %%
vo=collateral.values

# %%
plt.figure(figsize=(6,5),facecolor="#FFF3C8")


plt.title("Saving Balance",color="k",size="large",weight="bold")

plt.ylabel("Employement Type",color="#458393")
plt.xlabel("Collateral Values",color="#458393")

plt.grid()
plt.gca().set_axisbelow(True)

plt.bar(co,vo,color="#458393")

plt.show()

# %% [markdown]
# ### conclusion : There are 19 private borrowers whose collateral value is high

# %%
Approval=loan.groupby("Approval_Reason")["Application_ID"].mean()

# %%
a=Approval.index

# %%
b=Approval.values

# %%
plt.figure(figsize=(9,9),facecolor="#F9F0E0")
plt.title("Approval Reasons",size="large",weight="bold")
plt.pie(b,labels=a,autopct="%1.1f%%",shadow=0.40)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### conclusion : 17.2% of borrowers are those whose approval reason is pending

# %%
channel=loan.groupby("Application_Channel")["Application_ID"].mean()

# %%
c=channel.index

# %%
n=channel.values

# %%
plt.figure(figsize=(6,4),facecolor="#FFF7EB")

plt.title("Channel Analysis",color="#063B00",size="large",weight="bold")

plt.xlabel("Borrower",color="#063B00")
plt.ylabel("Appliaction Channel",color="#063B00")

plt.grid(axis="x")
plt.gca().set_axisbelow(True)

colors=["#827148"]
plt.barh(c,n,color=colors)

plt.show()

# %% [markdown]
# ### conclusion : There are 1816 who got their loan approved through the branch

# %%
history=loan.groupby("Credit_History")["Credit_Score"].sum().sort_values()

# %%
a=history.index

# %%
b=history.values

# %%
plt.figure(figsize=(6,5),facecolor="#E8F5E9")

plt.title("Loan History Prefromance",color="#321E48",size="large",weight="bold")


plt.xlabel("Credit History Performance",color="#321E48")
plt.ylabel("Appliaction ID",color="#321E48")

plt.grid()

plt.plot(a,b,marker="o",mfc="#133458",mec="#FAF7BB",ms=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### conclusion : In the loan history, performance is Good

# %%
high=loan.groupby("City")["Application_ID"].mean().sort_values(ascending=False).head(3)

# %%
c=high.index

# %%
t=high.values

# %%
plt.figure(figsize=(8,5),facecolor="#FFE2E2")

plt.title("Top 3 Cities",color="#BD4444",size="large",weight="bold")


plt.xlabel("Cities",color="k")
plt.ylabel("Borrower")

plt.grid(axis="y",alpha=0.4)
plt.gca().set_axisbelow(True)

plt.bar(c,t,color=["#FFDF82","#FDEB9E","#FFF9D2"],width=0.7)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### conclusion : There are three cities, Jaipur is one of them, it will take the most loans.

# %%
data = pd.crosstab(
    loan["Loan_Purpose"],
    loan["Loan_Status"])

data.plot(kind="bar", figsize=(8,5),color=["#BA5A5A","#F7E49B"])


plt.title("Loan Status by Loan Purpose",size="large",weight="bold")


plt.xlabel("Loan Purpose")
plt.ylabel("Number of Applications")

plt.grid(axis="y", alpha=0.6)
plt.gca().set_axisbelow(True)

plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### conclusion : Loan approval patterns vary across risk levels, loan purposes, and applicant characteristics, helping support better loan decisions.

# %%
x=loan["Application_ID"]

# %%
y=loan["Savings_Balance"]

# %%
plt.figure(figsize=(6,5),facecolor="#EEE0CC")

plt.title("Customer Collateral Values",size="large",weight="bold")
)

plt.xlabel("Savings Balance")
plt.ylabel("Borrower")

plt.xticks(rotation=45)
plt.scatter(y,x,marker="H",alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### conclusion : The chart shows how savings balance varies among different borrowers, helping to understand their financial position.

# %% [markdown]
# # **Risk Aanlysis**
# ### The analysis helps identify important factors related to loan approval, rejection, applicant risk, and loan application patterns.

# %%
loan.groupby("Risk_Level")["Loan_Status"]

# %%
loan["Loan_Status"]
# Out:
# 0       Approved
# 1       Rejected
# 2       Rejected
# 3       Approved
# 4       Approved
#           ...
# 3515    Rejected
# 3516    Approved
# 3517    Approved
# 3518    Approved
# 3519    Approved
# Name: Loan_Status, Length: 3520, dtype: str

# %%
risk_status = pd.crosstab(
    loan["Risk_Level"],
    loan["Loan_Status"],
    normalize="index") * 100

risk_status.plot(kind="bar",figsize=(8,5),color=["#FFD400","#FF0052"])

plt.title("Loan Approval Status by Risk Level",
          fontsize=14, fontweight="bold")

plt.xlabel("Risk Level")
plt.ylabel("Percentage (%)")

plt.grid(axis="y", alpha=0.4)
plt.gca().set_axisbelow(True)

plt.xticks(rotation=0)
plt.legend(title="Loan Status")

plt.tight_layout()
plt.show()

# %% [markdown]
# # ***Project Outcome***
#
# ## Through this project, the following data-analysis skills are demonstrated:
#
# **Data loading
# Data cleaning
# Missing-value handling
# Duplicate detection
# Data type analysis
# Pandas filtering
# GroupBy analysis
# Statistical analysis
# Data visualization
# Risk analysis
# Applicant segmentation
# Business insight generation**
#
# ### Overall, the project demonstrates the complete workflow of a Data Analyst — from raw data to meaningful business insights.
# **This project demonstrates how Python-based data analysis can be used to understand loan applications, identify risk factors, and support better data-driven loan decisions.**
